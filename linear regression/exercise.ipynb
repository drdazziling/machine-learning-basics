# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df1 = pd.read_csv("percapitaincome.csv")
df1
# Out:
#     year           PCI
# 0   1970   3399.299037
# 1   1971   3768.297935
# 2   1972   4251.175484
# 3   1973   4804.463248
# 4   1974   5576.514583
# 5   1975   5998.144346
# 6   1976   7062.131392
# 7   1977   7100.126170
# 8   1978   7247.967035
# 9   1979   7602.912681
# 10  1980   8355.968120
# 11  1981   9434.390652
# 12  1982   9619.438377
# 13  1983  10416.536590
# 14  1984  10790.328720
# 15  1985  11018.955850
# 16  1986  11482.891530
# 17  1987  12974.806620
# 18  1988  15080.283450
# 19  1989  16426.725480
# 20  1990  16838.673200
# 21  1991  17266.097690
# 22  1992  16412.083090
# 23  1993  15875.586730
# 24  1994  15755.820270
# 25  1995  16369.317250
# 26  1996  16699.826680
# 27  1997  17310.757750
# 28  1998  16622.671870
# 29  1999  17581.024140
# 30  2000  18987.382410
# 31  2001  18601.397240
# 32  2002  19232.175560
# 33  2003  22739.426280
# 34  2004  25719.147150
# 35  2005  29198.055690
# 36  2006  32738.262900
# 37  2007  36144.481220
# 38  2008  37446.486090
# ...

# %%
# %matplotlib inline
plt.xlabel('year',fontsize=20)
plt.ylabel('per capita income in (NT$))')
plt.scatter(df1.year,df1.PCI, color='red', marker='*')

# %%
reg = linear_model.LinearRegression()  #object creation for linear_regression model
reg.fit(df1[['year']],df1[['PCI']])
# Out:
# LinearRegression()

# %%
reg.predict([[2023]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[43774.08932009]])

# %%
# %matplotlib inline
plt.xlabel('year',fontsize=20)
plt.ylabel('predicted income',fontsize=20)
plt.scatter(df.year,df.PCI, color='red', marker='+')
plt.plot(df1.year,reg.predict(df1[['year']]),color='blue')

# %%
df2 = pd.read_csv("year.csv")
df2
# Out:
#     year
# 0   2017
# 1   2018
# 2   2019
# 3   2020
# 4   2021
# 5   2022
# 6   2023
# 7   2024
# 8   2025
# 9   2026
# 10  2027
# 11  2028
# 12  2029

# %%
p = reg.predict(df2)
df2['predicted_prices'] = p
df2
# Out:
#     year  predicted_prices
# 0   2017      38803.298869
# 1   2018      39631.763944
# 2   2019      40460.229019
# 3   2020      41288.694094
# 4   2021      42117.159170
# 5   2022      42945.624245
# 6   2023      43774.089320
# 7   2024      44602.554395
# 8   2025      45431.019471
# 9   2026      46259.484546
# 10  2027      47087.949621
# 11  2028      47916.414696
# 12  2029      48744.879771

# %%
# %matplotlib inline
plt.xlabel('year',fontsize=20)
plt.ylabel('predicted income',fontsize=20)
plt.scatter(df1.year,df1.PCI, color='red', marker='+')
plt.plot(df2.year,reg.predict(df2[['year']]),color='blue')
